# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
img = cv2.imread('../Barcode-Reader-CV-Proj/Test Cases-20241123/01 - lol easy.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10,8))
plt.imshow(img_rgb)
plt.axis('off')  # Hide axes
plt.show()
